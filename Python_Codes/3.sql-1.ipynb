# %%
pip install sqlalchemy pyodbc
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.0 MB/s eta 0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

# Load CSV
prod_df = pd.read_csv(
    r"D:\SQL\Supply_Chain_Mgmt\Data\products_clean.csv"
)

# SQL Server connection
engine = create_engine(
    "mssql+pyodbc://DESKTOP-S7R831B\\SQLEXPRESS/SupplychainDB?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# Load table
prod_df.to_sql(
    "products",
    engine,
    if_exists="append",
    index=False
)

print("Loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File d:\Programs Files\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:2127, in Connection._exec_insertmany_context(self, dialect, context)
#    2126     else:
# -> 2127         dialect.do_execute(
#    2128             cursor,
#    2129             sub_stmt,
#    2130             sub_params,
#    2131             context,
#    2132         )
#    2134 except BaseException as e:
#
# File d:\Programs Files\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# ...

# %%
prod_df.columns = [
    "Product_Card_Id",
    "Product_Name",
    "Category_Id",
    "Category_Name",
    "Department_Id",
    "Department_Name",
    "Product_Price"
]

# %%
print(prod_df.columns.tolist())
# Out:
# ['Product_Card_Id', 'Product_Name', 'Category_Id', 'Category_Name', 'Department_Id', 'Department_Name', 'Product_Price']

# %%
prod_df.to_sql(
    "products",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 118

# %%
prod_df.head(5).to_sql(
    "products",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 5

# %%
import pandas as pd
ord_df = pd.read_csv(
    r"D:\SQL\Supply_Chain_Mgmt\Python_Codes\orders.csv",
    sep=";",
)
ord_df
# Out:
#        Order Id order date (DateOrders)     Order Status        Order City  \
# 0         77202         1/31/2018 22:56         COMPLETE            Bekasi
# 1         75939         1/13/2018 12:27          PENDING           Bikaner
# 2         75938         1/13/2018 12:06           CLOSED           Bikaner
# 3         75937         1/13/2018 11:45         COMPLETE        Townsville
# 4         75936         1/13/2018 11:24  PENDING_PAYMENT        Townsville
# ...         ...                     ...              ...               ...
# 65747     26773         1/26/2016 19:25           CLOSED  Ho Chi Minh City
# 65748     26463          1/22/2016 6:49  PENDING_PAYMENT             Ezhou
# 65749     26383          1/21/2016 2:47           CLOSED             Tawau
# 65750     26327          1/20/2016 7:10          ON_HOLD          Semarang
# 65751     26118          1/17/2016 5:56  SUSPECTED_FRAUD            Ratlam
#
# ...

# %%
ord_df.info()
ord_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65752 entries, 0 to 65751
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order Id                 65752 non-null  int64
#  1   order date (DateOrders)  65752 non-null  object
#  2   Order Status             65752 non-null  object
#  3   Order City               65752 non-null  object
#  4   Order State              65752 non-null  object
#  5   Order Country            65752 non-null  object
#  6   Order Region             65752 non-null  object
#  7   Market                   65752 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 4.0+ MB
# Order Id                   0
# order date (DateOrders)    0
# Order Status               0
# Order City                 0
# Order State                0
# Order Country              0
# Order Region               0
# Market                     0
# dtype: int64

# %%
ord_df["order date (DateOrders)"] = pd.to_datetime(
    ord_df["order date (DateOrders)"]
)

# %%
ord_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65752 entries, 0 to 65751
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order Id                 65752 non-null  int64
#  1   order date (DateOrders)  65752 non-null  datetime64[ns]
#  2   Order Status             65752 non-null  object
#  3   Order City               65752 non-null  object
#  4   Order State              65752 non-null  object
#  5   Order Country            65752 non-null  object
#  6   Order Region             65752 non-null  object
#  7   Market                   65752 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 4.0+ MB

# %%
ord_df.columns = [
    "Order_Id",
    "Order_Date",
    "Order_Status",
    "Order_City",
    "Order_State",
    "Order_Country",
    "Order_Region",
    "Market"
]

# %%
print(ord_df.columns)
# Out:
# Index(['Order_Id', 'Order_Date', 'Order_Status', 'Order_City', 'Order_State',
#        'Order_Country', 'Order_Region', 'Market'],
#       dtype='object')

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mssql+pyodbc://DESKTOP-S7R831B\\SQLEXPRESS/SupplychainDB?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

ord_df.to_sql(
    "orders",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 252

# %%
ord_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65752 entries, 0 to 65751
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_Id       65752 non-null  int64
#  1   Order_Date     65752 non-null  datetime64[ns]
#  2   Order_Status   65752 non-null  object
#  3   Order_City     65752 non-null  object
#  4   Order_State    65752 non-null  object
#  5   Order_Country  65752 non-null  object
#  6   Order_Region   65752 non-null  object
#  7   Market         65752 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 4.0+ MB

# %%
ship_df = pd.read_csv(
    r"D:\SQL\Supply_Chain_Mgmt\Python_Codes\shipping.csv",
    sep=";"
)

# %%
ship_df
# Out:
#        Order Id   Shipping Mode    Delivery Status  Late_delivery_risk  \
# 0         77202  Standard Class   Advance shipping                   0
# 1         75939  Standard Class      Late delivery                   1
# 2         75938  Standard Class   Shipping on time                   0
# 3         75937  Standard Class   Advance shipping                   0
# 4         75936  Standard Class   Advance shipping                   0
# ...         ...             ...                ...                 ...
# 65747     26773     First Class      Late delivery                   1
# 65748     26463  Standard Class   Shipping on time                   0
# 65749     26383    Second Class      Late delivery                   1
# 65750     26327  Standard Class   Advance shipping                   0
# 65751     26118  Standard Class  Shipping canceled                   0
#
#        Days for shipping (real)  Days for shipment (scheduled)  \
# ...

# %%
ship_df.info()
ship_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65752 entries, 0 to 65751
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Order Id                       65752 non-null  int64
#  1   Shipping Mode                  65752 non-null  object
#  2   Delivery Status                65752 non-null  object
#  3   Late_delivery_risk             65752 non-null  int64
#  4   Days for shipping (real)       65752 non-null  int64
#  5   Days for shipment (scheduled)  65752 non-null  int64
#  6   shipping date (DateOrders)     65752 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 3.5+ MB
# Order Id                         0
# Shipping Mode                    0
# Delivery Status                  0
# Late_delivery_risk               0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# shipping date (DateOrders)       0
# dtype: int64

# %%
ship_df["shipping date (DateOrders)"] = pd.to_datetime(
    ship_df["shipping date (DateOrders)"]
)

# %%
ship_df.columns = [
    "Order_Id",
    "Shipping_Mode",
    "Delivery_Status",
    "Late_Delivery_Risk",
    "Days_For_Shipping_Real",
    "Days_For_Shipment_Scheduled",
    "Shipping_Date"
]

# %%
ship_df.head()
# Out:
#    Order_Id   Shipping_Mode   Delivery_Status  Late_Delivery_Risk  \
# 0     77202  Standard Class  Advance shipping                   0
# 1     75939  Standard Class     Late delivery                   1
# 2     75938  Standard Class  Shipping on time                   0
# 3     75937  Standard Class  Advance shipping                   0
# 4     75936  Standard Class  Advance shipping                   0
#
#    Days_For_Shipping_Real  Days_For_Shipment_Scheduled       Shipping_Date
# 0                       3                            4 2018-02-03 22:56:00
# 1                       5                            4 2018-01-18 12:27:00
# 2                       4                            4 2018-01-17 12:06:00
# 3                       3                            4 2018-01-16 11:45:00
# 4                       2                            4 2018-01-15 11:24:00

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mssql+pyodbc://DESKTOP-S7R831B\\SQLEXPRESS/SupplychainDB?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

ship_df.to_sql(
    "shipping",
    engine,
    if_exists="append",
    index=False,
    chunksize=250,
    method="multi"
)
# Out:
# 65752

# %%
sales_df = pd.read_csv(
    r"D:\SQL\Supply_Chain_Mgmt\Python_Codes\sales_fact.csv",
    sep=";"
)
sales_df
# Out:
#         Order Id  Customer Id  Product Card Id       Sales  \
# 0          77202        20755             1360  327.750000
# 1          75939        19492             1360  327.750000
# 2          75938        19491             1360  327.750000
# 3          75937        19490             1360  327.750000
# 4          75936        19489             1360  327.750000
# ...          ...          ...              ...         ...
# 180506     26043         1005             1004  399.980011
# 180507     26037         9141             1004  399.980011
# 180508     26024          291             1004  399.980011
# 180509     26022         2813             1004  399.980011
# 180510     26018         7547             1004  399.980011
#
#         Order Item Quantity  Benefit per order  Order Profit Per Order
# 0                         1          91.250000               91.250000
# 1                         1        -249.089996             -249.089996
# ...

# %%
sales_df.info()
sales_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180511 entries, 0 to 180510
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Order Id                180511 non-null  int64
#  1   Customer Id             180511 non-null  int64
#  2   Product Card Id         180511 non-null  int64
#  3   Sales                   180511 non-null  float64
#  4   Order Item Quantity     180511 non-null  int64
#  5   Benefit per order       180511 non-null  float64
#  6   Order Profit Per Order  180511 non-null  float64
# dtypes: float64(3), int64(4)
# memory usage: 9.6 MB
# Order Id                  0
# Customer Id               0
# Product Card Id           0
# Sales                     0
# Order Item Quantity       0
# Benefit per order         0
# Order Profit Per Order    0
# dtype: int64

# %%
sales_df.columns = [
    "Order_Id",
    "Customer_Id",
    "Product_Card_Id",
    "Sales",
    "Order_Item_Quantity",
    "Benefit_Per_Order",
    "Order_Profit_Per_Order"
]

# %%
sales_df.to_sql(
    "sales_fact",
    engine,
    if_exists="append",
    index=False,
    chunksize=5000
)
# Out:
# 7988
